# %%
# This Notebook contains all the experimental figures used in the submitted paper.

# Import required methods
import sys
sys.path.append('./../../')

from plot.synthetic_expt_plotter import plot_gdp_expt, plot_gdp_expt_with_deltas, plot_case_study

# %%
expt_no = 2

# %%
# EXPT_DATA_FILE = './../../data/expt_output/expt-data-case-swp-old-new-lp-{}.csv'
EXPT_DATA_FILE = './../../data/expt_output/expt-data-adp-gdp-specialized-{}-k-50.csv'
PLOT_OUTPUT_FILE = './../../data/expt_output/adp-specialized.pdf'

# 3Star Query with Delta Plots
xmax = 1e6
g00_ymax = 1e4
g01_ymin = 0
g11_ymin = 0.9
g00_arrow_point = None

DATA_ALPHA = 0.7
plot_gdp_expt(7, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = 2, 
g00_ymax=g00_ymax, DATA_ALPHA=DATA_ALPHA, xmax = xmax, g00_arrow_point = 5, g00_arrow_expt1="ilp_results", g00_arrow_expt2="specialized_adp", single_plot=True)
# Out:
# Saving plot to ./../../data/expt_output/adp-specialized.pdf

# %%
# EXPT_DATA_FILE = './../../data/expt_output/expt-data-case-swp-old-new-lp-{}.csv'
EXPT_DATA_FILE = './../../data/expt_output/expt-data-dpvs-gdp-specialized-{}.csv'
PLOT_OUTPUT_FILE = None # To show output in notebook
PLOT_OUTPUT_FILE = './../../data/expt_output/dpvs-specialized.pdf'


# 3Star Query with Delta Plots
xmax = 1e9
g00_ymax = 1e4
g01_ymax = 1e4 
g01_ymin = 0
g10_ymax = 1e3*7
g11_ymax = 2
g11_ymin = 0.9
g00_arrow_point = None

DATA_ALPHA = 0.7
plot_gdp_expt(7, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = 2, 
g00_ymax=g00_ymax, g01_ymax=g01_ymax, g11_ymax = g11_ymax, g10_ymax= g10_ymax, DATA_ALPHA=DATA_ALPHA, xmax = xmax, g00_arrow_point = 13, g00_arrow_expt1="specialized_dpvs", g00_arrow_expt2="ilp_results", single_plot=True)
# Out:
# /Users/neha/research/gdp_code/expt/viz/../../plot/synthetic_expt_plotter.py:193: ParserWarning: Skipping line 364: expected 30 fields, saw 31
# Skipping line 374: expected 30 fields, saw 31
#
#   expt_data = pd.read_csv(EXPT_DATA_FILE.format(case_no), on_bad_lines='warn')
# Saving plot to ./../../data/expt_output/dpvs-specialized.pdf

# %%
# EXPT_DATA_FILE = './../../data/expt_output/expt-data-case-swp-old-new-lp-{}.csv'
EXPT_DATA_FILE = './../../data/expt_output/expt-data-swp-gdp-specialized-{}.csv'
PLOT_OUTPUT_FILE = './../../data/expt_output/swp-specialized.pdf'

# 3Star Query with Delta Plots
xmax = 1e7
g00_ymax = 1e4
g01_ymax = 1e4 
g01_ymin = 0
g10_ymax = 1e3*7
g11_ymax = 2
g11_ymin = 0.9
g00_arrow_point = None

DATA_ALPHA = 0.7
plot_gdp_expt(7, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = 2, 
g00_ymax=g00_ymax, g01_ymax=g01_ymax, g11_ymax = g11_ymax, g10_ymax= g10_ymax, DATA_ALPHA=DATA_ALPHA, xmax = xmax, g00_arrow_point = 8, g00_arrow_expt1="ilp_results", g00_arrow_expt2="specialized_swp", single_plot=True)
# Out:
# /Users/neha/research/gdp_code/expt/viz/../../plot/synthetic_expt_plotter.py:193: ParserWarning: Skipping line 244: expected 29 fields, saw 30
# Skipping line 279: expected 29 fields, saw 30
#
#   expt_data = pd.read_csv(EXPT_DATA_FILE.format(case_no), on_bad_lines='warn')
# Saving plot to ./../../data/expt_output/swp-specialized.pdf

# %%
# EXPT_DATA_FILE = './../../data/expt_output/expt-data-case-swp-old-new-lp-{}.csv'
EXPT_DATA_FILE = './../../data/expt_output/expt-data-adp-gdp-sj-ucq-{}.csv'
PLOT_OUTPUT_FILE = './../../data/expt_output/sj-adp.pdf'

# 3Star Query with Delta Plots
xmax = 1e6 *2
g00_ymax = 1e4
g01_ymax = 1e4
g01_ymin = 0
g10_ymax = 1e3*7
g11_ymin = 0.9
g00_arrow_point = None

DATA_ALPHA = 0.7
plot_gdp_expt(9, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = 3, 
g00_ymax=g00_ymax, g01_ymax=g01_ymax, g10_ymax= g10_ymax, DATA_ALPHA=DATA_ALPHA, xmax = xmax)
# Out:
# /Users/neha/research/gdp_code/expt/viz/../../plot/synthetic_expt_plotter.py:193: ParserWarning: Skipping line 262: expected 28 fields, saw 29
#
#   expt_data = pd.read_csv(EXPT_DATA_FILE.format(case_no), on_bad_lines='warn')
# Saving plot to ./../../data/expt_output/sj-adp.pdf

# %%
# EXPT_DATA_FILE = './../../data/expt_output/expt-data-case-swp-old-new-lp-{}.csv'
EXPT_DATA_FILE = './../../data/expt_output/expt-data-swp-gdp-sj-ucq-{}.csv'
PLOT_OUTPUT_FILE = './../../data/expt_output/sj-swp.pdf'

# 3Star Query with Delta Plots
xmax = 1e6
g00_ymax = 1e4
g01_ymax = 1e4
g01_ymin = 0
g10_ymax = 1e3*7
g11_ymin = 0.9
g00_arrow_point = None

DATA_ALPHA = 0.7
plot_gdp_expt(9, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = 2, 
g00_ymax=g00_ymax, g01_ymax=g01_ymax, g10_ymax= g10_ymax, DATA_ALPHA=DATA_ALPHA, xmax = xmax)
# Out:
# /Users/neha/research/gdp_code/expt/viz/../../plot/synthetic_expt_plotter.py:193: ParserWarning: Skipping line 41: expected 27 fields, saw 28
# Skipping line 103: expected 27 fields, saw 28
#
#   expt_data = pd.read_csv(EXPT_DATA_FILE.format(case_no), on_bad_lines='warn')
# Saving plot to ./../../data/expt_output/sj-swp.pdf

# %%
# EXPT_DATA_FILE = './../../data/expt_output/expt-data-case-swp-old-new-lp-{}.csv'
EXPT_DATA_FILE = './../../data/expt_output/expt-data-dpvs-gdp-sj-ucq-{}.csv'
PLOT_OUTPUT_FILE = './../../data/expt_output/sj-dpvs.pdf'

# 3Star Query with Delta Plots
xmax = 1e6
g00_ymax = 1e5
g01_ymax = 1e4
g01_ymin = 0
g10_ymax = 1e3*7
g11_ymin = 0.9
g00_arrow_point = None

DATA_ALPHA = 0.7
plot_gdp_expt(9, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = 2, 
g00_ymax=g00_ymax, g01_ymax=g01_ymax, g10_ymax= g10_ymax, DATA_ALPHA=DATA_ALPHA, xmax = xmax)
# Out:
# /Users/neha/research/gdp_code/expt/viz/../../plot/synthetic_expt_plotter.py:193: ParserWarning: Skipping line 415: expected 27 fields, saw 28
#
#   expt_data = pd.read_csv(EXPT_DATA_FILE.format(case_no), on_bad_lines='warn')
# Saving plot to ./../../data/expt_output/sj-dpvs.pdf

# %%
# EXPT_DATA_FILE = './../../data/expt_output/expt-data-case-swp-old-new-lp-{}.csv'
EXPT_DATA_FILE = './../../data/expt_output/expt-data-case-swp-old-new-lp-{}.csv'
PLOT_OUTPUT_FILE = './../../data/expt_output/swp-new-old-ilp.pdf'

xmax = 1e6 *2
g00_ymax = 1e4 * 5
g01_ymax = 2
g01_ymin = 0
g11_ymin = 0.9
g00_arrow_point = None

DATA_ALPHA = 0.7
plot_gdp_expt(7, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = 2, 
g00_ymax=g00_ymax, g01_ymax=g01_ymax, g10_ymax= g10_ymax, DATA_ALPHA=DATA_ALPHA, xmax = xmax, g00_arrow_point = 12, g00_arrow_expt1="ilp_results", g00_arrow_expt2="ilp_results_old", single_plot=False, g01_arrow_point=8, g01_arrow_expt1="ilp_results", g01_arrow_expt2="lp_results_old")
# Out:
# Saving plot to ./../../data/expt_output/swp-new-old-ilp.pdf

# %%
# EXPT_DATA_FILE = './../../data/expt_output/expt-data-case-swp-old-new-lp-{}.csv'
EXPT_DATA_FILE = './../../data/expt_output/expt-data-case-study.csv'
PLOT_OUTPUT_FILE = './../../data/expt_output/GDP-case-study.pdf'

plot_case_study(EXPT_DATA_FILE = EXPT_DATA_FILE, xmax = 1e5, xmin = 1e3*5, g01_arrow_point = 3, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)
# Out:
# Saving plot to ./../../data/expt_output/GDP-case-study.pdf
